# %%
import pandas
import sys
import os
import json
sys.path.insert(0, os.getcwd())
from helpers import recursive_find, read_json, create_results_table

pandas.set_option('display.max_columns', None)  # or 1000
pandas.set_option('display.max_rows', None)  # or 1000
pandas.set_option('display.max_colwidth', None)  # or 199

# %%
# Read in the experiment json files. One experiment means one package at once version
# across splices (versions of a single dependencny) and predictors
experiments = list(recursive_find("artifacts/tests/", "experiment.json"))
print('Found %s experiment files.' % len(experiments))
# Out:
# Found 216 experiment files.

# %%
df = create_results_table(experiments)
display(df)
# Out:
#                     original  \
# 0      complex-double/lib.so
# 1      complex-double/lib.so
# 2      complex-double/lib.so
# 3      complex-double/lib.so
# 4      complex-double/lib.so
# 5      complex-double/lib.so
# 6      complex-double/lib.so
# 7      complex-double/lib.so
# 8      complex-double/lib.so
# 9      complex-double/lib.so
# 10     complex-double/lib.so
# 11     complex-double/lib.so
# 12     complex-double/lib.so
# 13     complex-double/lib.so
# 14     complex-double/lib.so
# 15     complex-double/lib.so
# 16     complex-double/lib.so
# 17     complex-double/lib.so
# 18     complex-double/lib.so
# 19     complex-double/lib.so
# 20     complex-double/lib.so
# 21     complex-double/lib.so
# 22     complex-double/lib.so
# 23     complex-double/lib.so
# 24     complex-double/lib.so
# 25     complex-double/lib.so
# 26     complex-double/lib.so
# 27     complex-double/lib.so
# 28     complex-double/lib.so
# 29     complex-double/lib.so
# 30     complex-double/lib.so
# 31     complex-double/lib.so
# 32     complex-double/lib.so
# 33     complex-double/lib.so
# 34     complex-double/lib.so
# 35     complex-double/lib.so
# 36     complex-double/lib.so
# 37     complex-double/lib.so
# 38     complex-double/lib.so
# 39     complex-double/lib.so
# 40     complex-double/lib.so
# 41     complex-double/lib.so
# 42     complex-double/lib.so
# 43     complex-double/lib.so
# 44     complex-double/lib.so
# 45     complex-double/lib.so
# 46     complex-double/lib.so
# 47     complex-double/lib.so
# 48     complex-double/lib.so
# 49     complex-double/lib.so
# 50     complex-double/lib.so
# 51     complex-double/lib.so
# 52     complex-double/lib.so
# 53     complex-double/lib.so
# 54     complex-double/lib.so
# 55     complex-double/lib.so
# 56     complex-double/lib.so
# 57     complex-double/lib.so
# 58     complex-double/lib.so
# 59     complex-double/lib.so
# 60     complex-double/lib.so
# 61     complex-double/lib.so
# 62     complex-double/lib.so
# 63     complex-double/lib.so
# 64     complex-double/lib.so
# 65     complex-double/lib.so
# 66     complex-double/lib.so
# 67     complex-double/lib.so
# 68     complex-double/lib.so
# 69     complex-double/lib.so
# 70     complex-double/lib.so
# 71     complex-double/lib.so
# 72     complex-double/lib.so
# 73     complex-double/lib.so
# 74     complex-double/lib.so
# 75     complex-double/lib.so
# 76     complex-double/lib.so
# 77     complex-double/lib.so
# 78     complex-double/lib.so
# 79     complex-double/lib.so
# 80     complex-double/lib.so
# 81     complex-double/lib.so
# 82     complex-double/lib.so
# 83     complex-double/lib.so
# 84     complex-double/lib.so
# 85     complex-double/lib.so
# 86     complex-double/lib.so
# 87     complex-double/lib.so
# 88     complex-double/lib.so
# 89     complex-double/lib.so
# 90     complex-double/lib.so
# 91     complex-double/lib.so
# 92     complex-double/lib.so
# 93     complex-double/lib.so
# 94     complex-double/lib.so
# 95     complex-double/lib.so
# 96   function-pointer/lib.so
# 97   function-pointer/lib.so
# 98   function-pointer/lib.so
# 99   function-pointer/lib.so
# 100  function-pointer/lib.so
# 101  function-pointer/lib.so
# 102  function-pointer/lib.so
# 103  function-pointer/lib.so
# 104  function-pointer/lib.so
# 105  function-pointer/lib.so
# 106  function-pointer/lib.so
# 107  function-pointer/lib.so
# 108  function-pointer/lib.so
# 109  function-pointer/lib.so
# 110  function-pointer/lib.so
# 111  function-pointer/lib.so
# 112  function-pointer/lib.so
# 113  function-pointer/lib.so
# 114  function-pointer/lib.so
# 115  function-pointer/lib.so
# 116  function-pointer/lib.so
# 117  function-pointer/lib.so
# 118  function-pointer/lib.so
# 119  function-pointer/lib.so
# 120  function-pointer/lib.so
# 121  function-pointer/lib.so
# 122  function-pointer/lib.so
# 123  function-pointer/lib.so
# 124  function-pointer/lib.so
# 125  function-pointer/lib.so
# 126  function-pointer/lib.so
# 127  function-pointer/lib.so
# 128  function-pointer/lib.so
# 129  function-pointer/lib.so
# 130  function-pointer/lib.so
# 131  function-pointer/lib.so
# 132  function-pointer/lib.so
# 133  function-pointer/lib.so
# 134  function-pointer/lib.so
# 135  function-pointer/lib.so
# 136  function-pointer/lib.so
# 137  function-pointer/lib.so
# 138  function-pointer/lib.so
# 139  function-pointer/lib.so
# 140  function-pointer/lib.so
# 141  function-pointer/lib.so
# 142  function-pointer/lib.so
# 143  function-pointer/lib.so
# 144  function-pointer/lib.so
# 145  function-pointer/lib.so
# 146  function-pointer/lib.so
# 147  function-pointer/lib.so
# 148  function-pointer/lib.so
# 149  function-pointer/lib.so
# 150  function-pointer/lib.so
# 151  function-pointer/lib.so
# 152  function-pointer/lib.so
# 153  function-pointer/lib.so
# 154  function-pointer/lib.so
# 155  function-pointer/lib.so
# 156  function-pointer/lib.so
# 157  function-pointer/lib.so
# 158  function-pointer/lib.so
# 159  function-pointer/lib.so
# 160  function-pointer/lib.so
# 161  function-pointer/lib.so
# 162  function-pointer/lib.so
# 163  function-pointer/lib.so
# 164  function-pointer/lib.so
# 165  function-pointer/lib.so
# 166  function-pointer/lib.so
# 167  function-pointer/lib.so
# 168  function-pointer/lib.so
# 169  function-pointer/lib.so
# 170  function-pointer/lib.so
# 171  function-pointer/lib.so
# 172  function-pointer/lib.so
# 173  function-pointer/lib.so
# 174  function-pointer/lib.so
# 175  function-pointer/lib.so
# 176  function-pointer/lib.so
# 177  function-pointer/lib.so
# 178  function-pointer/lib.so
# 179  function-pointer/lib.so
# 180  function-pointer/lib.so
# 181  function-pointer/lib.so
# 182  function-pointer/lib.so
# 183  function-pointer/lib.so
# 184  function-pointer/lib.so
# 185  function-pointer/lib.so
# 186  function-pointer/lib.so
# 187  function-pointer/lib.so
# 188  function-pointer/lib.so
# 189  function-pointer/lib.so
# 190  function-pointer/lib.so
# 191  function-pointer/lib.so
# 192  function-pointer/lib.so
# 193  function-pointer/lib.so
# 194  function-pointer/lib.so
# 195  function-pointer/lib.so
# 196  function-pointer/lib.so
# 197  function-pointer/lib.so
# 198  function-pointer/lib.so
# 199  function-pointer/lib.so
# 200  function-pointer/lib.so
# 201  function-pointer/lib.so
# 202  function-pointer/lib.so
# 203  function-pointer/lib.so
# 204  function-pointer/lib.so
# 205  function-pointer/lib.so
# 206  function-pointer/lib.so
# 207  function-pointer/lib.so
# 208  function-pointer/lib.so
# 209  function-pointer/lib.so
# 210  function-pointer/lib.so
# 211  function-pointer/lib.so
# 212  function-pointer/lib.so
# 213  function-pointer/lib.so
# 214  function-pointer/lib.so
# 215  function-pointer/lib.so
# 216  function-pointer/lib.so
# 217  function-pointer/lib.so
# 218  function-pointer/lib.so
# 219  function-pointer/lib.so
# 220  function-pointer/lib.so
# 221  function-pointer/lib.so
# 222  function-pointer/lib.so
# 223  function-pointer/lib.so
# 224  function-pointer/lib.so
# 225  function-pointer/lib.so
# 226  function-pointer/lib.so
# 227  function-pointer/lib.so
# 228  function-pointer/lib.so
# 229  function-pointer/lib.so
# 230  function-pointer/lib.so
# 231  function-pointer/lib.so
# 232  function-pointer/lib.so
# 233  function-pointer/lib.so
# 234  function-pointer/lib.so
# 235  function-pointer/lib.so
# 236  function-pointer/lib.so
# 237  function-pointer/lib.so
# 238  function-pointer/lib.so
# 239  function-pointer/lib.so
# 240  function-pointer/lib.so
# 241  function-pointer/lib.so
# 242  function-pointer/lib.so
# 243  function-pointer/lib.so
# 244  function-pointer/lib.so
# 245  function-pointer/lib.so
# 246  function-pointer/lib.so
# 247  function-pointer/lib.so
# 248  function-pointer/lib.so
# 249  function-pointer/lib.so
# 250  function-pointer/lib.so
# 251  function-pointer/lib.so
# 252  function-pointer/lib.so
# 253  function-pointer/lib.so
# 254  function-pointer/lib.so
# 255  function-pointer/lib.so
# 256  function-pointer/lib.so
# 257  function-pointer/lib.so
# 258  function-pointer/lib.so
# 259  function-pointer/lib.so
# 260  function-pointer/lib.so
# 261  function-pointer/lib.so
# 262  function-pointer/lib.so
# 263  function-pointer/lib.so
# 264  function-pointer/lib.so
# 265  function-pointer/lib.so
# 266  function-pointer/lib.so
# 267  function-pointer/lib.so
# 268  function-pointer/lib.so
# 269  function-pointer/lib.so
# 270  function-pointer/lib.so
# 271  function-pointer/lib.so
# 272  function-pointer/lib.so
# 273  function-pointer/lib.so
# 274  function-pointer/lib.so
# 275  function-pointer/lib.so
# 276  function-pointer/lib.so
# 277  function-pointer/lib.so
# 278  function-pointer/lib.so
# 279  function-pointer/lib.so
# 280  function-pointer/lib.so
# 281  function-pointer/lib.so
# 282  function-pointer/lib.so
# 283  function-pointer/lib.so
# 284  function-pointer/lib.so
# 285  function-pointer/lib.so
# 286  function-pointer/lib.so
# 287  function-pointer/lib.so
# 288  function-pointer/lib.so
# 289  function-pointer/lib.so
# 290  function-pointer/lib.so
# 291  function-pointer/lib.so
# 292  function-pointer/lib.so
# 293  function-pointer/lib.so
# 294  function-pointer/lib.so
# 295  function-pointer/lib.so
# 296  function-pointer/lib.so
# 297  function-pointer/lib.so
# 298  function-pointer/lib.so
# 299  function-pointer/lib.so
# 300  function-pointer/lib.so
# 301  function-pointer/lib.so
# 302  function-pointer/lib.so
# 303  function-pointer/lib.so
# 304  function-pointer/lib.so
# 305  function-pointer/lib.so
# 306  function-pointer/lib.so
# 307  function-pointer/lib.so
# 308  function-pointer/lib.so
# 309  function-pointer/lib.so
# 310  function-pointer/lib.so
# 311  function-pointer/lib.so
# 312  function-pointer/lib.so
# 313  function-pointer/lib.so
# 314  function-pointer/lib.so
# 315  function-pointer/lib.so
# 316  function-pointer/lib.so
# 317  function-pointer/lib.so
# 318  function-pointer/lib.so
# 319  function-pointer/lib.so
# 320  function-pointer/lib.so
# 321  function-pointer/lib.so
# 322  function-pointer/lib.so
# 323  function-pointer/lib.so
# 324  function-pointer/lib.so
# 325  function-pointer/lib.so
# 326  function-pointer/lib.so
# 327  function-pointer/lib.so
# 328  function-pointer/lib.so
# 329  function-pointer/lib.so
# 330  function-pointer/lib.so
# 331  function-pointer/lib.so
# 332  function-pointer/lib.so
# 333  function-pointer/lib.so
# 334  function-pointer/lib.so
# 335  function-pointer/lib.so
# 336  function-pointer/lib.so
# 337  function-pointer/lib.so
# 338  function-pointer/lib.so
# 339  function-pointer/lib.so
# 340  function-pointer/lib.so
# 341  function-pointer/lib.so
# 342  function-pointer/lib.so
# 343  function-pointer/lib.so
# 344  function-pointer/lib.so
# 345  function-pointer/lib.so
# 346  function-pointer/lib.so
# 347  function-pointer/lib.so
# 348  function-pointer/lib.so
# 349  function-pointer/lib.so
# 350  function-pointer/lib.so
# 351  function-pointer/lib.so
# 352  function-pointer/lib.so
# 353  function-pointer/lib.so
# 354  function-pointer/lib.so
# 355  function-pointer/lib.so
# 356  function-pointer/lib.so
# 357  function-pointer/lib.so
# 358  function-pointer/lib.so
# 359  function-pointer/lib.so
# 360  function-pointer/lib.so
# 361  function-pointer/lib.so
# 362  function-pointer/lib.so
# 363  function-pointer/lib.so
# 364  function-pointer/lib.so
# 365  function-pointer/lib.so
# 366  function-pointer/lib.so
# 367  function-pointer/lib.so
# 368  function-pointer/lib.so
# 369  function-pointer/lib.so
# 370  function-pointer/lib.so
# 371  function-pointer/lib.so
# 372  function-pointer/lib.so
# 373  function-pointer/lib.so
# 374  function-pointer/lib.so
# 375  function-pointer/lib.so
# 376  function-pointer/lib.so
# 377  function-pointer/lib.so
# 378  function-pointer/lib.so
# 379  function-pointer/lib.so
# 380  function-pointer/lib.so
# 381  function-pointer/lib.so
# 382  function-pointer/lib.so
# 383  function-pointer/lib.so
# 384  function-pointer/lib.so
# 385  function-pointer/lib.so
# 386  function-pointer/lib.so
# 387  function-pointer/lib.so
# 388  function-pointer/lib.so
# 389  function-pointer/lib.so
# 390  function-pointer/lib.so
# 391  function-pointer/lib.so
# 392  function-pointer/lib.so
# 393  function-pointer/lib.so
# 394  function-pointer/lib.so
# 395  function-pointer/lib.so
# 396  function-pointer/lib.so
# 397  function-pointer/lib.so
# 398  function-pointer/lib.so
# 399  function-pointer/lib.so
# 400  function-pointer/lib.so
# 401  function-pointer/lib.so
# 402  function-pointer/lib.so
# 403  function-pointer/lib.so
# 404  function-pointer/lib.so
# 405  function-pointer/lib.so
# 406  function-pointer/lib.so
# 407  function-pointer/lib.so
# 408  function-pointer/lib.so
# 409  function-pointer/lib.so
# 410  function-pointer/lib.so
# 411  function-pointer/lib.so
# 412  function-pointer/lib.so
# 413  function-pointer/lib.so
# 414  function-pointer/lib.so
# 415  function-pointer/lib.so
# 416  function-pointer/lib.so
# 417  function-pointer/lib.so
# 418  function-pointer/lib.so
# 419  function-pointer/lib.so
# 420  function-pointer/lib.so
# 421  function-pointer/lib.so
# 422  function-pointer/lib.so
# 423  function-pointer/lib.so
# 424  function-pointer/lib.so
# 425  function-pointer/lib.so
# 426  function-pointer/lib.so
# 427  function-pointer/lib.so
# 428  function-pointer/lib.so
# 429  function-pointer/lib.so
# 430  function-pointer/lib.so
# 431  function-pointer/lib.so
# 432  function-pointer/lib.so
# 433  function-pointer/lib.so
# 434  function-pointer/lib.so
# 435  function-pointer/lib.so
# 436  function-pointer/lib.so
# 437  function-pointer/lib.so
# 438  function-pointer/lib.so
# 439  function-pointer/lib.so
# 440  function-pointer/lib.so
# 441  function-pointer/lib.so
# 442  function-pointer/lib.so
# 443  function-pointer/lib.so
# 444  function-pointer/lib.so
# 445  function-pointer/lib.so
# 446  function-pointer/lib.so
# 447  function-pointer/lib.so
# 448  function-pointer/lib.so
# 449  function-pointer/lib.so
# 450  function-pointer/lib.so
# 451  function-pointer/lib.so
# 452  function-pointer/lib.so
# 453  function-pointer/lib.so
# 454  function-pointer/lib.so
# 455  function-pointer/lib.so
# 456  function-pointer/lib.so
# 457  function-pointer/lib.so
# 458  function-pointer/lib.so
# 459  function-pointer/lib.so
# 460  function-pointer/lib.so
# 461  function-pointer/lib.so
# 462  function-pointer/lib.so
# 463  function-pointer/lib.so
# 464  function-pointer/lib.so
# 465  function-pointer/lib.so
# 466  function-pointer/lib.so
# 467  function-pointer/lib.so
# 468  function-pointer/lib.so
# 469  function-pointer/lib.so
# 470  function-pointer/lib.so
# 471  function-pointer/lib.so
# 472  function-pointer/lib.so
# 473  function-pointer/lib.so
# 474  function-pointer/lib.so
# 475  function-pointer/lib.so
# 476  function-pointer/lib.so
# 477  function-pointer/lib.so
# 478  function-pointer/lib.so
# 479  function-pointer/lib.so
# 480  function-pointer/lib.so
# 481  function-pointer/lib.so
# 482  function-pointer/lib.so
# 483  function-pointer/lib.so
# 484  function-pointer/lib.so
# 485  function-pointer/lib.so
# 486  function-pointer/lib.so
# 487  function-pointer/lib.so
# 488  function-pointer/lib.so
# 489  function-pointer/lib.so
# 490  function-pointer/lib.so
# 491  function-pointer/lib.so
# 492  function-pointer/lib.so
# 493  function-pointer/lib.so
# 494  function-pointer/lib.so
# 495  function-pointer/lib.so
# 496  function-pointer/lib.so
# 497  function-pointer/lib.so
# 498  function-pointer/lib.so
# 499  function-pointer/lib.so
# 500  function-pointer/lib.so
# 501  function-pointer/lib.so
# 502  function-pointer/lib.so
# 503  function-pointer/lib.so
# 504  function-pointer/lib.so
# 505  function-pointer/lib.so
# 506  function-pointer/lib.so
# 507  function-pointer/lib.so
# 508  function-pointer/lib.so
# 509  function-pointer/lib.so
# 510  function-pointer/lib.so
# 511  function-pointer/lib.so
# 512  function-pointer/lib.so
# 513  function-pointer/lib.so
# 514  function-pointer/lib.so
# 515  function-pointer/lib.so
# 516  function-pointer/lib.so
# 517  function-pointer/lib.so
# 518  function-pointer/lib.so
# 519  function-pointer/lib.so
# 520  function-pointer/lib.so
# 521  function-pointer/lib.so
# 522  function-pointer/lib.so
# 523  function-pointer/lib.so
# 524  function-pointer/lib.so
# 525  function-pointer/lib.so
# 526  function-pointer/lib.so
# 527  function-pointer/lib.so
# 528  function-pointer/lib.so
# 529  function-pointer/lib.so
# 530  function-pointer/lib.so
# 531  function-pointer/lib.so
# 532  function-pointer/lib.so
# 533  function-pointer/lib.so
# 534  function-pointer/lib.so
# 535  function-pointer/lib.so
# 536  function-pointer/lib.so
# 537  function-pointer/lib.so
# 538  function-pointer/lib.so
# 539  function-pointer/lib.so
# 540  function-pointer/lib.so
# 541  function-pointer/lib.so
# 542  function-pointer/lib.so
# 543  function-pointer/lib.so
# 544  function-pointer/lib.so
# 545  function-pointer/lib.so
# 546  function-pointer/lib.so
# 547  function-pointer/lib.so
# 548  function-pointer/lib.so
# 549  function-pointer/lib.so
# 550  function-pointer/lib.so
# 551  function-pointer/lib.so
# 552  function-pointer/lib.so
# 553  function-pointer/lib.so
# 554  function-pointer/lib.so
# 555  function-pointer/lib.so
# 556  function-pointer/lib.so
# 557  function-pointer/lib.so
# 558  function-pointer/lib.so
# 559  function-pointer/lib.so
# 560  function-pointer/lib.so
# 561  function-pointer/lib.so
# 562  function-pointer/lib.so
# 563  function-pointer/lib.so
# 564  function-pointer/lib.so
# 565  function-pointer/lib.so
# 566  function-pointer/lib.so
# 567  function-pointer/lib.so
# 568  function-pointer/lib.so
# 569  function-pointer/lib.so
# 570  function-pointer/lib.so
# 571  function-pointer/lib.so
# 572  function-pointer/lib.so
# 573  function-pointer/lib.so
# 574  function-pointer/lib.so
# 575  function-pointer/lib.so
# 576  function-pointer/lib.so
# 577  function-pointer/lib.so
# 578  function-pointer/lib.so
# 579  function-pointer/lib.so
# 580  function-pointer/lib.so
# 581  function-pointer/lib.so
# 582  function-pointer/lib.so
# 583  function-pointer/lib.so
# 584  function-pointer/lib.so
# 585  function-pointer/lib.so
# 586  function-pointer/lib.so
# 587  function-pointer/lib.so
# 588  function-pointer/lib.so
# 589  function-pointer/lib.so
# 590  function-pointer/lib.so
# 591  function-pointer/lib.so
# 592  function-pointer/lib.so
# 593  function-pointer/lib.so
# 594  function-pointer/lib.so
# 595  function-pointer/lib.so
# 596  function-pointer/lib.so
# 597  function-pointer/lib.so
# 598  function-pointer/lib.so
# 599  function-pointer/lib.so
# 600  function-pointer/lib.so
# 601  function-pointer/lib.so
# 602  function-pointer/lib.so
# 603  function-pointer/lib.so
# 604  function-pointer/lib.so
# 605  function-pointer/lib.so
# 606  function-pointer/lib.so
# 607  function-pointer/lib.so
# 608  function-pointer/lib.so
# 609  function-pointer/lib.so
# 610  function-pointer/lib.so
# 611  function-pointer/lib.so
# 612  function-pointer/lib.so
# 613  function-pointer/lib.so
# 614  function-pointer/lib.so
# 615  function-pointer/lib.so
# 616  function-pointer/lib.so
# 617  function-pointer/lib.so
# 618  function-pointer/lib.so
# 619  function-pointer/lib.so
# 620  function-pointer/lib.so
# 621  function-pointer/lib.so
# 622  function-pointer/lib.so
# 623  function-pointer/lib.so
# 624  function-pointer/lib.so
# 625  function-pointer/lib.so
# 626  function-pointer/lib.so
# 627  function-pointer/lib.so
# 628  function-pointer/lib.so
# 629  function-pointer/lib.so
# 630  function-pointer/lib.so
# 631  function-pointer/lib.so
# 632  function-pointer/lib.so
# 633  function-pointer/lib.so
# 634  function-pointer/lib.so
# 635  function-pointer/lib.so
# 636  function-pointer/lib.so
# 637  function-pointer/lib.so
# 638  function-pointer/lib.so
# 639  function-pointer/lib.so
# 640  function-pointer/lib.so
# 641  function-pointer/lib.so
# 642  function-pointer/lib.so
# 643  function-pointer/lib.so
# 644  function-pointer/lib.so
# 645  function-pointer/lib.so
# 646  function-pointer/lib.so
# 647  function-pointer/lib.so
# 648  function-pointer/lib.so
# 649  function-pointer/lib.so
# 650  function-pointer/lib.so
# 651  function-pointer/lib.so
# 652  function-pointer/lib.so
# 653  function-pointer/lib.so
# 654  function-pointer/lib.so
# 655  function-pointer/lib.so
# 656  function-pointer/lib.so
# 657  function-pointer/lib.so
# 658  function-pointer/lib.so
# 659  function-pointer/lib.so
# 660  function-pointer/lib.so
# 661  function-pointer/lib.so
# 662  function-pointer/lib.so
# 663  function-pointer/lib.so
# 664  function-pointer/lib.so
# 665  function-pointer/lib.so
# 666  function-pointer/lib.so
# 667  function-pointer/lib.so
# 668  function-pointer/lib.so
# 669  function-pointer/lib.so
# 670  function-pointer/lib.so
# 671  function-pointer/lib.so
# 672              enum/lib.so
# 673              enum/lib.so
# 674              enum/lib.so
# 675              enum/lib.so
# 676              enum/lib.so
# 677              enum/lib.so
# 678              enum/lib.so
# 679              enum/lib.so
# 680              enum/lib.so
# 681              enum/lib.so
# 682              enum/lib.so
# 683              enum/lib.so
# 684              enum/lib.so
# 685              enum/lib.so
# 686              enum/lib.so
# 687              enum/lib.so
# 688              enum/lib.so
# 689              enum/lib.so
# 690              enum/lib.so
# 691              enum/lib.so
# 692              enum/lib.so
# 693              enum/lib.so
# 694              enum/lib.so
# 695              enum/lib.so
# 696              enum/lib.so
# 697              enum/lib.so
# 698              enum/lib.so
# 699              enum/lib.so
# 700              enum/lib.so
# 701              enum/lib.so
# 702              enum/lib.so
# 703              enum/lib.so
# 704              enum/lib.so
# 705              enum/lib.so
# 706              enum/lib.so
# 707              enum/lib.so
# 708              enum/lib.so
# 709              enum/lib.so
# 710              enum/lib.so
# 711              enum/lib.so
# 712              enum/lib.so
# 713              enum/lib.so
# 714              enum/lib.so
# 715              enum/lib.so
# 716              enum/lib.so
# 717              enum/lib.so
# 718              enum/lib.so
# 719              enum/lib.so
# 720              enum/lib.so
# 721              enum/lib.so
# 722              enum/lib.so
# 723              enum/lib.so
# 724              enum/lib.so
# 725              enum/lib.so
# 726              enum/lib.so
# 727              enum/lib.so
# 728              enum/lib.so
# 729              enum/lib.so
# 730              enum/lib.so
# 731              enum/lib.so
# 732              enum/lib.so
# 733              enum/lib.so
# 734              enum/lib.so
# 735              enum/lib.so
# 736              enum/lib.so
# 737              enum/lib.so
# 738              enum/lib.so
# 739              enum/lib.so
# 740              enum/lib.so
# 741              enum/lib.so
# 742              enum/lib.so
# 743              enum/lib.so
# 744              enum/lib.so
# 745              enum/lib.so
# 746              enum/lib.so
# 747              enum/lib.so
# 748              enum/lib.so
# 749              enum/lib.so
# 750              enum/lib.so
# 751              enum/lib.so
# 752              enum/lib.so
# 753              enum/lib.so
# 754              enum/lib.so
# 755              enum/lib.so
# 756              enum/lib.so
# 757              enum/lib.so
# 758              enum/lib.so
# 759              enum/lib.so
# 760              enum/lib.so
# 761              enum/lib.so
# 762              enum/lib.so
# 763              enum/lib.so
# 764              enum/lib.so
# 765              enum/lib.so
# 766              enum/lib.so
# 767              enum/lib.so
# 768              enum/lib.so
# 769              enum/lib.so
# 770              enum/lib.so
# 771              enum/lib.so
# 772              enum/lib.so
# 773              enum/lib.so
# 774              enum/lib.so
# 775              enum/lib.so
# 776              enum/lib.so
# 777              enum/lib.so
# 778              enum/lib.so
# 779              enum/lib.so
# 780              enum/lib.so
# 781              enum/lib.so
# 782              enum/lib.so
# 783              enum/lib.so
# 784              enum/lib.so
# 785              enum/lib.so
# 786              enum/lib.so
# 787              enum/lib.so
# 788              enum/lib.so
# 789              enum/lib.so
# 790              enum/lib.so
# 791              enum/lib.so
# 792              enum/lib.so
# 793              enum/lib.so
# 794              enum/lib.so
# 795              enum/lib.so
# 796              enum/lib.so
# 797              enum/lib.so
# 798              enum/lib.so
# 799              enum/lib.so
# 800              enum/lib.so
# 801              enum/lib.so
# 802              enum/lib.so
# 803              enum/lib.so
# 804              enum/lib.so
# 805              enum/lib.so
# 806              enum/lib.so
# 807              enum/lib.so
# 808              enum/lib.so
# 809              enum/lib.so
# 810              enum/lib.so
# 811              enum/lib.so
# 812              enum/lib.so
# 813              enum/lib.so
# 814              enum/lib.so
# 815              enum/lib.so
# 816              enum/lib.so
# 817              enum/lib.so
# 818              enum/lib.so
# 819              enum/lib.so
# 820              enum/lib.so
# 821              enum/lib.so
# 822              enum/lib.so
# 823              enum/lib.so
# 824              enum/lib.so
# 825              enum/lib.so
# 826              enum/lib.so
# 827              enum/lib.so
# 828              enum/lib.so
# 829              enum/lib.so
# 830              enum/lib.so
# 831              enum/lib.so
# 832              enum/lib.so
# 833              enum/lib.so
# 834              enum/lib.so
# 835              enum/lib.so
# 836              enum/lib.so
# 837              enum/lib.so
# 838              enum/lib.so
# 839              enum/lib.so
# 840              enum/lib.so
# 841              enum/lib.so
# 842              enum/lib.so
# 843              enum/lib.so
# 844              enum/lib.so
# 845              enum/lib.so
# 846              enum/lib.so
# 847              enum/lib.so
# 848              enum/lib.so
# 849              enum/lib.so
# 850              enum/lib.so
# 851              enum/lib.so
# 852              enum/lib.so
# 853              enum/lib.so
# 854              enum/lib.so
# 855              enum/lib.so
# 856              enum/lib.so
# 857              enum/lib.so
# 858              enum/lib.so
# 859              enum/lib.so
# 860              enum/lib.so
# 861              enum/lib.so
# 862              enum/lib.so
# 863              enum/lib.so
#
#                                                          changed  \
# 0                   complex-double/breaks/narrow_to_float/lib.so
# 1                   complex-double/breaks/narrow_to_float/lib.so
# 2                   complex-double/breaks/narrow_to_float/lib.so
# 3                   complex-double/breaks/narrow_to_float/lib.so
# 4                   complex-double/breaks/narrow_to_float/lib.so
# 5                   complex-double/breaks/narrow_to_float/lib.so
# 6                   complex-double/breaks/narrow_to_float/lib.so
# 7                   complex-double/breaks/narrow_to_float/lib.so
# 8                   complex-double/breaks/narrow_to_float/lib.so
# 9                   complex-double/breaks/narrow_to_float/lib.so
# 10                  complex-double/breaks/narrow_to_float/lib.so
# 11                  complex-double/breaks/narrow_to_float/lib.so
# 12                  complex-double/breaks/narrow_to_float/lib.so
# 13                  complex-double/breaks/narrow_to_float/lib.so
# 14                  complex-double/breaks/narrow_to_float/lib.so
# 15                  complex-double/breaks/narrow_to_float/lib.so
# 16                  complex-double/breaks/narrow_to_float/lib.so
# 17                  complex-double/breaks/narrow_to_float/lib.so
# 18                  complex-double/breaks/narrow_to_float/lib.so
# 19                  complex-double/breaks/narrow_to_float/lib.so
# 20                  complex-double/breaks/narrow_to_float/lib.so
# 21                  complex-double/breaks/narrow_to_float/lib.so
# 22                  complex-double/breaks/narrow_to_float/lib.so
# 23                  complex-double/breaks/narrow_to_float/lib.so
# 24                  complex-double/breaks/narrow_to_float/lib.so
# 25                  complex-double/breaks/narrow_to_float/lib.so
# 26                  complex-double/breaks/narrow_to_float/lib.so
# 27                  complex-double/breaks/narrow_to_float/lib.so
# 28                  complex-double/breaks/narrow_to_float/lib.so
# 29                  complex-double/breaks/narrow_to_float/lib.so
# 30                  complex-double/breaks/narrow_to_float/lib.so
# 31                  complex-double/breaks/narrow_to_float/lib.so
# 32                  complex-double/breaks/narrow_to_float/lib.so
# 33                  complex-double/breaks/narrow_to_float/lib.so
# 34                  complex-double/breaks/narrow_to_float/lib.so
# 35                  complex-double/breaks/narrow_to_float/lib.so
# 36                  complex-double/breaks/narrow_to_float/lib.so
# 37                  complex-double/breaks/narrow_to_float/lib.so
# 38                  complex-double/breaks/narrow_to_float/lib.so
# 39                  complex-double/breaks/narrow_to_float/lib.so
# 40                  complex-double/breaks/narrow_to_float/lib.so
# 41                  complex-double/breaks/narrow_to_float/lib.so
# 42                  complex-double/breaks/narrow_to_float/lib.so
# 43                  complex-double/breaks/narrow_to_float/lib.so
# 44                  complex-double/breaks/narrow_to_float/lib.so
# 45                  complex-double/breaks/narrow_to_float/lib.so
# 46                  complex-double/breaks/narrow_to_float/lib.so
# 47                  complex-double/breaks/narrow_to_float/lib.so
# 48                 complex-double/breaks/narrow_to_double/lib.so
# 49                 complex-double/breaks/narrow_to_double/lib.so
# 50                 complex-double/breaks/narrow_to_double/lib.so
# 51                 complex-double/breaks/narrow_to_double/lib.so
# 52                 complex-double/breaks/narrow_to_double/lib.so
# 53                 complex-double/breaks/narrow_to_double/lib.so
# 54                 complex-double/breaks/narrow_to_double/lib.so
# 55                 complex-double/breaks/narrow_to_double/lib.so
# 56                 complex-double/breaks/narrow_to_double/lib.so
# 57                 complex-double/breaks/narrow_to_double/lib.so
# 58                 complex-double/breaks/narrow_to_double/lib.so
# 59                 complex-double/breaks/narrow_to_double/lib.so
# 60                 complex-double/breaks/narrow_to_double/lib.so
# 61                 complex-double/breaks/narrow_to_double/lib.so
# 62                 complex-double/breaks/narrow_to_double/lib.so
# 63                 complex-double/breaks/narrow_to_double/lib.so
# 64                 complex-double/breaks/narrow_to_double/lib.so
# 65                 complex-double/breaks/narrow_to_double/lib.so
# 66                 complex-double/breaks/narrow_to_double/lib.so
# 67                 complex-double/breaks/narrow_to_double/lib.so
# 68                 complex-double/breaks/narrow_to_double/lib.so
# 69                 complex-double/breaks/narrow_to_double/lib.so
# 70                 complex-double/breaks/narrow_to_double/lib.so
# 71                 complex-double/breaks/narrow_to_double/lib.so
# 72                 complex-double/breaks/narrow_to_double/lib.so
# 73                 complex-double/breaks/narrow_to_double/lib.so
# 74                 complex-double/breaks/narrow_to_double/lib.so
# 75                 complex-double/breaks/narrow_to_double/lib.so
# 76                 complex-double/breaks/narrow_to_double/lib.so
# 77                 complex-double/breaks/narrow_to_double/lib.so
# 78                 complex-double/breaks/narrow_to_double/lib.so
# 79                 complex-double/breaks/narrow_to_double/lib.so
# 80                 complex-double/breaks/narrow_to_double/lib.so
# 81                 complex-double/breaks/narrow_to_double/lib.so
# 82                 complex-double/breaks/narrow_to_double/lib.so
# 83                 complex-double/breaks/narrow_to_double/lib.so
# 84                 complex-double/breaks/narrow_to_double/lib.so
# 85                 complex-double/breaks/narrow_to_double/lib.so
# 86                 complex-double/breaks/narrow_to_double/lib.so
# 87                 complex-double/breaks/narrow_to_double/lib.so
# 88                 complex-double/breaks/narrow_to_double/lib.so
# 89                 complex-double/breaks/narrow_to_double/lib.so
# 90                 complex-double/breaks/narrow_to_double/lib.so
# 91                 complex-double/breaks/narrow_to_double/lib.so
# 92                 complex-double/breaks/narrow_to_double/lib.so
# 93                 complex-double/breaks/narrow_to_double/lib.so
# 94                 complex-double/breaks/narrow_to_double/lib.so
# 95                 complex-double/breaks/narrow_to_double/lib.so
# 96     function-pointer/breaks/return_widen_no_conversion/lib.so
# 97     function-pointer/breaks/return_widen_no_conversion/lib.so
# 98     function-pointer/breaks/return_widen_no_conversion/lib.so
# 99     function-pointer/breaks/return_widen_no_conversion/lib.so
# 100    function-pointer/breaks/return_widen_no_conversion/lib.so
# 101    function-pointer/breaks/return_widen_no_conversion/lib.so
# 102    function-pointer/breaks/return_widen_no_conversion/lib.so
# 103    function-pointer/breaks/return_widen_no_conversion/lib.so
# 104    function-pointer/breaks/return_widen_no_conversion/lib.so
# 105    function-pointer/breaks/return_widen_no_conversion/lib.so
# 106    function-pointer/breaks/return_widen_no_conversion/lib.so
# 107    function-pointer/breaks/return_widen_no_conversion/lib.so
# 108    function-pointer/breaks/return_widen_no_conversion/lib.so
# 109    function-pointer/breaks/return_widen_no_conversion/lib.so
# 110    function-pointer/breaks/return_widen_no_conversion/lib.so
# 111    function-pointer/breaks/return_widen_no_conversion/lib.so
# 112    function-pointer/breaks/return_widen_no_conversion/lib.so
# 113    function-pointer/breaks/return_widen_no_conversion/lib.so
# 114    function-pointer/breaks/return_widen_no_conversion/lib.so
# 115    function-pointer/breaks/return_widen_no_conversion/lib.so
# 116    function-pointer/breaks/return_widen_no_conversion/lib.so
# 117    function-pointer/breaks/return_widen_no_conversion/lib.so
# 118    function-pointer/breaks/return_widen_no_conversion/lib.so
# 119    function-pointer/breaks/return_widen_no_conversion/lib.so
# 120    function-pointer/breaks/return_widen_no_conversion/lib.so
# 121    function-pointer/breaks/return_widen_no_conversion/lib.so
# 122    function-pointer/breaks/return_widen_no_conversion/lib.so
# 123    function-pointer/breaks/return_widen_no_conversion/lib.so
# 124    function-pointer/breaks/return_widen_no_conversion/lib.so
# 125    function-pointer/breaks/return_widen_no_conversion/lib.so
# 126    function-pointer/breaks/return_widen_no_conversion/lib.so
# 127    function-pointer/breaks/return_widen_no_conversion/lib.so
# 128    function-pointer/breaks/return_widen_no_conversion/lib.so
# 129    function-pointer/breaks/return_widen_no_conversion/lib.so
# 130    function-pointer/breaks/return_widen_no_conversion/lib.so
# 131    function-pointer/breaks/return_widen_no_conversion/lib.so
# 132    function-pointer/breaks/return_widen_no_conversion/lib.so
# 133    function-pointer/breaks/return_widen_no_conversion/lib.so
# 134    function-pointer/breaks/return_widen_no_conversion/lib.so
# 135    function-pointer/breaks/return_widen_no_conversion/lib.so
# 136    function-pointer/breaks/return_widen_no_conversion/lib.so
# 137    function-pointer/breaks/return_widen_no_conversion/lib.so
# 138    function-pointer/breaks/return_widen_no_conversion/lib.so
# 139    function-pointer/breaks/return_widen_no_conversion/lib.so
# 140    function-pointer/breaks/return_widen_no_conversion/lib.so
# 141    function-pointer/breaks/return_widen_no_conversion/lib.so
# 142    function-pointer/breaks/return_widen_no_conversion/lib.so
# 143    function-pointer/breaks/return_widen_no_conversion/lib.so
# 144     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 145     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 146     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 147     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 148     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 149     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 150     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 151     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 152     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 153     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 154     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 155     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 156     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 157     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 158     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 159     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 160     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 161     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 162     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 163     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 164     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 165     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 166     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 167     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 168     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 169     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 170     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 171     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 172     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 173     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 174     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 175     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 176     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 177     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 178     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 179     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 180     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 181     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 182     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 183     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 184     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 185     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 186     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 187     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 188     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 189     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 190     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 191     function-pointer/breaks/return_no_narrow_unsigned/lib.so
# 192     function-pointer/breaks/param_widen_no_conversion/lib.so
# 193     function-pointer/breaks/param_widen_no_conversion/lib.so
# 194     function-pointer/breaks/param_widen_no_conversion/lib.so
# 195     function-pointer/breaks/param_widen_no_conversion/lib.so
# 196     function-pointer/breaks/param_widen_no_conversion/lib.so
# 197     function-pointer/breaks/param_widen_no_conversion/lib.so
# 198     function-pointer/breaks/param_widen_no_conversion/lib.so
# 199     function-pointer/breaks/param_widen_no_conversion/lib.so
# 200     function-pointer/breaks/param_widen_no_conversion/lib.so
# 201     function-pointer/breaks/param_widen_no_conversion/lib.so
# 202     function-pointer/breaks/param_widen_no_conversion/lib.so
# 203     function-pointer/breaks/param_widen_no_conversion/lib.so
# 204     function-pointer/breaks/param_widen_no_conversion/lib.so
# 205     function-pointer/breaks/param_widen_no_conversion/lib.so
# 206     function-pointer/breaks/param_widen_no_conversion/lib.so
# 207     function-pointer/breaks/param_widen_no_conversion/lib.so
# 208     function-pointer/breaks/param_widen_no_conversion/lib.so
# 209     function-pointer/breaks/param_widen_no_conversion/lib.so
# 210     function-pointer/breaks/param_widen_no_conversion/lib.so
# 211     function-pointer/breaks/param_widen_no_conversion/lib.so
# 212     function-pointer/breaks/param_widen_no_conversion/lib.so
# 213     function-pointer/breaks/param_widen_no_conversion/lib.so
# 214     function-pointer/breaks/param_widen_no_conversion/lib.so
# 215     function-pointer/breaks/param_widen_no_conversion/lib.so
# 216     function-pointer/breaks/param_widen_no_conversion/lib.so
# 217     function-pointer/breaks/param_widen_no_conversion/lib.so
# 218     function-pointer/breaks/param_widen_no_conversion/lib.so
# 219     function-pointer/breaks/param_widen_no_conversion/lib.so
# 220     function-pointer/breaks/param_widen_no_conversion/lib.so
# 221     function-pointer/breaks/param_widen_no_conversion/lib.so
# 222     function-pointer/breaks/param_widen_no_conversion/lib.so
# 223     function-pointer/breaks/param_widen_no_conversion/lib.so
# 224     function-pointer/breaks/param_widen_no_conversion/lib.so
# 225     function-pointer/breaks/param_widen_no_conversion/lib.so
# 226     function-pointer/breaks/param_widen_no_conversion/lib.so
# 227     function-pointer/breaks/param_widen_no_conversion/lib.so
# 228     function-pointer/breaks/param_widen_no_conversion/lib.so
# 229     function-pointer/breaks/param_widen_no_conversion/lib.so
# 230     function-pointer/breaks/param_widen_no_conversion/lib.so
# 231     function-pointer/breaks/param_widen_no_conversion/lib.so
# 232     function-pointer/breaks/param_widen_no_conversion/lib.so
# 233     function-pointer/breaks/param_widen_no_conversion/lib.so
# 234     function-pointer/breaks/param_widen_no_conversion/lib.so
# 235     function-pointer/breaks/param_widen_no_conversion/lib.so
# 236     function-pointer/breaks/param_widen_no_conversion/lib.so
# 237     function-pointer/breaks/param_widen_no_conversion/lib.so
# 238     function-pointer/breaks/param_widen_no_conversion/lib.so
# 239     function-pointer/breaks/param_widen_no_conversion/lib.so
# 240  function-pointer/breaks/return_widen_with_conversion/lib.so
# 241  function-pointer/breaks/return_widen_with_conversion/lib.so
# 242  function-pointer/breaks/return_widen_with_conversion/lib.so
# 243  function-pointer/breaks/return_widen_with_conversion/lib.so
# 244  function-pointer/breaks/return_widen_with_conversion/lib.so
# 245  function-pointer/breaks/return_widen_with_conversion/lib.so
# 246  function-pointer/breaks/return_widen_with_conversion/lib.so
# 247  function-pointer/breaks/return_widen_with_conversion/lib.so
# 248  function-pointer/breaks/return_widen_with_conversion/lib.so
# 249  function-pointer/breaks/return_widen_with_conversion/lib.so
# 250  function-pointer/breaks/return_widen_with_conversion/lib.so
# 251  function-pointer/breaks/return_widen_with_conversion/lib.so
# 252  function-pointer/breaks/return_widen_with_conversion/lib.so
# 253  function-pointer/breaks/return_widen_with_conversion/lib.so
# 254  function-pointer/breaks/return_widen_with_conversion/lib.so
# 255  function-pointer/breaks/return_widen_with_conversion/lib.so
# 256  function-pointer/breaks/return_widen_with_conversion/lib.so
# 257  function-pointer/breaks/return_widen_with_conversion/lib.so
# 258  function-pointer/breaks/return_widen_with_conversion/lib.so
# 259  function-pointer/breaks/return_widen_with_conversion/lib.so
# 260  function-pointer/breaks/return_widen_with_conversion/lib.so
# 261  function-pointer/breaks/return_widen_with_conversion/lib.so
# 262  function-pointer/breaks/return_widen_with_conversion/lib.so
# 263  function-pointer/breaks/return_widen_with_conversion/lib.so
# 264  function-pointer/breaks/return_widen_with_conversion/lib.so
# 265  function-pointer/breaks/return_widen_with_conversion/lib.so
# 266  function-pointer/breaks/return_widen_with_conversion/lib.so
# 267  function-pointer/breaks/return_widen_with_conversion/lib.so
# 268  function-pointer/breaks/return_widen_with_conversion/lib.so
# 269  function-pointer/breaks/return_widen_with_conversion/lib.so
# 270  function-pointer/breaks/return_widen_with_conversion/lib.so
# 271  function-pointer/breaks/return_widen_with_conversion/lib.so
# 272  function-pointer/breaks/return_widen_with_conversion/lib.so
# 273  function-pointer/breaks/return_widen_with_conversion/lib.so
# 274  function-pointer/breaks/return_widen_with_conversion/lib.so
# 275  function-pointer/breaks/return_widen_with_conversion/lib.so
# 276  function-pointer/breaks/return_widen_with_conversion/lib.so
# 277  function-pointer/breaks/return_widen_with_conversion/lib.so
# 278  function-pointer/breaks/return_widen_with_conversion/lib.so
# 279  function-pointer/breaks/return_widen_with_conversion/lib.so
# 280  function-pointer/breaks/return_widen_with_conversion/lib.so
# 281  function-pointer/breaks/return_widen_with_conversion/lib.so
# 282  function-pointer/breaks/return_widen_with_conversion/lib.so
# 283  function-pointer/breaks/return_widen_with_conversion/lib.so
# 284  function-pointer/breaks/return_widen_with_conversion/lib.so
# 285  function-pointer/breaks/return_widen_with_conversion/lib.so
# 286  function-pointer/breaks/return_widen_with_conversion/lib.so
# 287  function-pointer/breaks/return_widen_with_conversion/lib.so
# 288    function-pointer/breaks/param_narrow_no_conversion/lib.so
# 289    function-pointer/breaks/param_narrow_no_conversion/lib.so
# 290    function-pointer/breaks/param_narrow_no_conversion/lib.so
# 291    function-pointer/breaks/param_narrow_no_conversion/lib.so
# 292    function-pointer/breaks/param_narrow_no_conversion/lib.so
# 293    function-pointer/breaks/param_narrow_no_conversion/lib.so
# 294    function-pointer/breaks/param_narrow_no_conversion/lib.so
# 295    function-pointer/breaks/param_narrow_no_conversion/lib.so
# 296    function-pointer/breaks/param_narrow_no_conversion/lib.so
# ...
# 848  missing-previously-found-symbols      clang-11  0.000015         symbols
# 849  missing-previously-found-exports      clang-11  0.000006         symbols
# 850                           abidiff      clang-11  0.007938      libabigail
# 851             abi-compliance-tester      clang-11  0.007595  abi-laboratory
# 852  missing-previously-found-symbols      clang-14  0.000023         symbols
# 853  missing-previously-found-exports      clang-14  0.000006         symbols
# 854                           abidiff      clang-14  0.009778      libabigail
# 855             abi-compliance-tester      clang-14  0.010826  abi-laboratory
# 856  missing-previously-found-symbols     gcc-7.5.0  0.000022         symbols
# 857  missing-previously-found-exports     gcc-7.5.0  0.000006         symbols
# 858                           abidiff     gcc-7.5.0  0.009155      libabigail
# 859             abi-compliance-tester     gcc-7.5.0  0.008221  abi-laboratory
# 860  missing-previously-found-symbols  dpcpp-2022.2  0.000014         symbols
# 861  missing-previously-found-exports  dpcpp-2022.2  0.000006         symbols
# 862                           abidiff  dpcpp-2022.2  0.009317      libabigail
# 863             abi-compliance-tester  dpcpp-2022.2  0.012259  abi-laboratory
#
#     prediction
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
# 30       False
# 31       False
# 32       False
# 33       False
# 34       False
# 35       False
# 36       False
# 37       False
# 38       False
# 39       False
# 40       False
# 41       False
# 42       False
# 43       False
# 44       False
# 45       False
# 46       False
# 47       False
# 48       False
# 49       False
# 50       False
# 51       False
# 52       False
# 53       False
# 54       False
# 55       False
# 56       False
# 57       False
# 58       False
# 59       False
# 60       False
# 61       False
# 62       False
# 63       False
# 64       False
# 65       False
# 66       False
# 67       False
# 68       False
# 69       False
# 70       False
# 71       False
# 72       False
# 73       False
# 74       False
# 75       False
# 76       False
# 77       False
# 78       False
# 79       False
# 80       False
# 81       False
# 82       False
# 83       False
# 84       False
# 85       False
# 86       False
# 87       False
# 88       False
# 89       False
# 90       False
# 91       False
# 92       False
# 93       False
# 94       False
# 95       False
# 96       False
# 97       False
# 98       False
# 99       False
# 100      False
# 101      False
# 102      False
# 103      False
# 104      False
# 105      False
# 106      False
# 107      False
# 108      False
# 109      False
# 110      False
# 111      False
# 112      False
# 113      False
# 114      False
# 115      False
# 116      False
# 117      False
# 118      False
# 119      False
# 120      False
# 121      False
# 122      False
# 123      False
# 124      False
# 125      False
# 126      False
# 127      False
# 128      False
# 129      False
# 130      False
# 131      False
# 132      False
# 133      False
# 134      False
# 135      False
# 136      False
# 137      False
# 138      False
# 139      False
# 140      False
# 141      False
# 142      False
# 143      False
# 144      False
# 145      False
# 146      False
# 147      False
# 148      False
# 149      False
# 150      False
# 151      False
# 152      False
# 153      False
# 154      False
# 155      False
# 156      False
# 157      False
# 158      False
# 159      False
# 160      False
# 161      False
# 162      False
# 163      False
# 164      False
# 165      False
# 166      False
# 167      False
# 168      False
# 169      False
# 170      False
# 171      False
# 172      False
# 173      False
# 174      False
# 175      False
# 176      False
# 177      False
# 178      False
# 179      False
# 180      False
# 181      False
# 182      False
# 183      False
# 184      False
# 185      False
# 186      False
# 187      False
# 188      False
# 189      False
# 190      False
# 191      False
# 192      False
# 193      False
# 194      False
# 195      False
# 196      False
# 197      False
# 198      False
# 199      False
# 200      False
# 201      False
# 202      False
# 203      False
# 204      False
# 205      False
# 206      False
# 207      False
# 208      False
# 209      False
# 210      False
# 211      False
# 212      False
# 213      False
# 214      False
# 215      False
# 216      False
# 217      False
# 218      False
# 219      False
# 220      False
# 221      False
# 222      False
# 223      False
# 224      False
# 225      False
# 226      False
# 227      False
# 228      False
# 229      False
# 230      False
# 231      False
# 232      False
# 233      False
# 234      False
# 235      False
# 236      False
# 237      False
# 238      False
# 239      False
# 240      False
# 241      False
# 242      False
# 243      False
# 244      False
# 245      False
# 246      False
# 247      False
# 248      False
# 249      False
# 250      False
# 251      False
# 252      False
# 253      False
# 254      False
# 255      False
# 256      False
# 257      False
# 258      False
# 259      False
# 260      False
# 261      False
# 262      False
# 263      False
# 264      False
# 265      False
# 266      False
# 267      False
# 268      False
# 269      False
# 270      False
# 271      False
# 272      False
# 273      False
# 274      False
# 275      False
# 276      False
# 277      False
# 278      False
# 279      False
# 280      False
# 281      False
# 282      False
# 283      False
# 284      False
# 285      False
# 286      False
# 287      False
# 288      False
# 289      False
# 290      False
# 291      False
# 292      False
# 293      False
# 294      False
# 295      False
# 296      False
# 297      False
# 298      False
# 299      False
# 300      False
# 301      False
# 302      False
# 303      False
# 304      False
# 305      False
# 306      False
# 307      False
# 308      False
# 309      False
# 310      False
# 311      False
# 312      False
# 313      False
# 314      False
# 315      False
# 316      False
# 317      False
# 318      False
# 319      False
# 320      False
# 321      False
# 322      False
# 323      False
# 324      False
# 325      False
# 326      False
# 327      False
# 328      False
# 329      False
# 330      False
# 331      False
# 332      False
# 333      False
# 334      False
# 335      False
# 336      False
# 337      False
# 338      False
# 339      False
# 340      False
# 341      False
# 342      False
# 343      False
# 344      False
# 345      False
# 346      False
# 347      False
# 348      False
# 349      False
# 350      False
# 351      False
# 352      False
# 353      False
# 354      False
# 355      False
# 356      False
# 357      False
# 358      False
# 359      False
# 360      False
# 361      False
# 362      False
# 363      False
# 364      False
# 365      False
# 366      False
# 367      False
# 368      False
# 369      False
# 370      False
# 371      False
# 372      False
# 373      False
# 374      False
# 375      False
# 376      False
# 377      False
# 378      False
# 379      False
# 380      False
# 381      False
# 382      False
# 383      False
# 384      False
# 385      False
# 386      False
# 387      False
# 388      False
# 389      False
# 390      False
# 391      False
# 392      False
# 393      False
# 394      False
# 395      False
# 396      False
# 397      False
# 398      False
# 399      False
# 400      False
# 401      False
# 402      False
# 403      False
# 404      False
# 405      False
# 406      False
# 407      False
# 408      False
# 409      False
# 410      False
# 411      False
# 412      False
# 413      False
# 414      False
# 415      False
# 416      False
# 417      False
# 418      False
# 419      False
# 420      False
# 421      False
# 422      False
# 423      False
# 424      False
# 425      False
# 426      False
# 427      False
# 428      False
# 429      False
# 430      False
# 431      False
# 432      False
# 433      False
# 434      False
# 435      False
# 436      False
# 437      False
# 438      False
# 439      False
# 440      False
# 441      False
# 442      False
# 443      False
# 444      False
# 445      False
# 446      False
# 447      False
# 448      False
# 449      False
# 450      False
# 451      False
# 452      False
# 453      False
# 454      False
# 455      False
# 456      False
# 457      False
# 458      False
# 459      False
# 460      False
# 461      False
# 462      False
# 463      False
# 464      False
# 465      False
# 466      False
# 467      False
# 468      False
# 469      False
# 470      False
# 471      False
# 472      False
# 473      False
# 474      False
# 475      False
# 476      False
# 477      False
# 478      False
# 479      False
# 480      False
# 481      False
# 482      False
# 483      False
# 484      False
# 485      False
# 486      False
# 487      False
# 488      False
# 489      False
# 490      False
# 491      False
# 492      False
# 493      False
# 494      False
# 495      False
# 496      False
# 497      False
# 498      False
# 499      False
# 500      False
# 501      False
# 502      False
# 503      False
# 504      False
# 505      False
# 506      False
# 507      False
# 508      False
# 509      False
# 510      False
# 511      False
# 512      False
# 513      False
# 514      False
# 515      False
# 516      False
# 517      False
# 518      False
# 519      False
# 520      False
# 521      False
# 522      False
# 523      False
# 524      False
# 525      False
# 526      False
# 527      False
# 528      False
# 529      False
# 530      False
# 531      False
# 532      False
# 533      False
# 534      False
# 535      False
# 536      False
# 537      False
# 538      False
# 539      False
# 540      False
# 541      False
# 542      False
# 543      False
# 544      False
# 545      False
# 546      False
# 547      False
# 548      False
# 549      False
# 550      False
# 551      False
# 552      False
# 553      False
# 554      False
# 555      False
# 556      False
# 557      False
# 558      False
# 559      False
# 560      False
# 561      False
# 562      False
# 563      False
# 564      False
# 565      False
# 566      False
# 567      False
# 568      False
# 569      False
# 570      False
# 571      False
# 572      False
# 573      False
# 574      False
# 575      False
# 576      False
# 577      False
# 578      False
# 579      False
# 580      False
# 581      False
# 582      False
# 583      False
# 584      False
# 585      False
# 586      False
# 587      False
# 588      False
# 589      False
# 590      False
# 591      False
# 592      False
# 593      False
# 594      False
# 595      False
# 596      False
# 597      False
# 598      False
# 599      False
# 600      False
# 601      False
# 602      False
# 603      False
# 604      False
# 605      False
# 606      False
# 607      False
# 608      False
# 609      False
# 610      False
# 611      False
# 612      False
# 613      False
# 614      False
# 615      False
# 616      False
# 617      False
# 618      False
# 619      False
# 620      False
# 621      False
# 622      False
# 623      False
# 624      False
# 625      False
# 626      False
# 627      False
# 628      False
# 629      False
# 630      False
# 631      False
# 632      False
# 633      False
# 634      False
# 635      False
# 636      False
# 637      False
# 638      False
# 639      False
# 640      False
# 641      False
# 642      False
# 643      False
# 644      False
# 645      False
# 646      False
# 647      False
# 648      False
# 649      False
# 650      False
# 651      False
# 652      False
# 653      False
# 654      False
# 655      False
# 656      False
# 657      False
# 658      False
# 659      False
# 660      False
# 661      False
# 662      False
# 663      False
# 664      False
# 665      False
# 666      False
# 667      False
# 668      False
# 669      False
# 670      False
# 671      False
# 672       True
# 673       True
# 674      False
# 675      False
# 676       True
# 677       True
# 678      False
# 679      False
# 680       True
# 681       True
# 682      False
# 683      False
# 684       True
# 685       True
# 686      False
# 687      False
# 688       True
# 689       True
# 690      False
# 691      False
# 692       True
# 693       True
# 694      False
# 695      False
# 696       True
# 697       True
# 698      False
# 699      False
# 700       True
# 701       True
# 702      False
# 703      False
# 704       True
# 705       True
# 706      False
# 707      False
# 708       True
# 709       True
# 710      False
# 711      False
# 712       True
# 713       True
# 714      False
# 715      False
# 716       True
# 717       True
# 718      False
# 719      False
# 720       True
# 721       True
# 722      False
# 723      False
# 724       True
# 725       True
# 726      False
# 727      False
# 728       True
# 729       True
# 730      False
# 731      False
# 732       True
# 733       True
# 734      False
# 735      False
# 736       True
# 737       True
# 738      False
# 739      False
# 740       True
# 741       True
# 742      False
# 743      False
# 744       True
# 745       True
# 746      False
# 747      False
# 748       True
# 749       True
# 750      False
# 751      False
# 752       True
# 753       True
# 754      False
# 755      False
# 756       True
# 757       True
# 758      False
# 759      False
# 760       True
# 761       True
# 762      False
# 763      False
# 764       True
# 765       True
# 766      False
# 767      False
# 768       True
# 769       True
# 770      False
# 771      False
# 772       True
# 773       True
# 774      False
# 775      False
# 776       True
# 777       True
# 778      False
# 779      False
# 780       True
# 781       True
# 782      False
# 783      False
# 784       True
# 785       True
# 786      False
# 787      False
# 788       True
# 789       True
# 790      False
# 791      False
# 792       True
# 793       True
# 794      False
# 795      False
# 796       True
# 797       True
# 798      False
# 799      False
# 800       True
# 801       True
# 802      False
# 803      False
# 804       True
# 805       True
# 806      False
# 807      False
# 808       True
# 809       True
# 810      False
# 811      False
# 812       True
# 813       True
# 814      False
# 815      False
# 816       True
# 817       True
# 818      False
# 819      False
# 820       True
# 821       True
# 822      False
# 823      False
# 824       True
# 825       True
# 826      False
# 827      False
# 828       True
# 829       True
# 830      False
# 831      False
# 832       True
# 833       True
# 834      False
# 835      False
# 836       True
# 837       True
# 838      False
# 839      False
# 840       True
# 841       True
# 842      False
# 843      False
# 844       True
# 845       True
# 846      False
# 847      False
# 848       True
# 849       True
# 850      False
# 851      False
# 852       True
# 853       True
# 854      False
# 855      False
# 856       True
# 857       True
# 858      False
# 859      False
# 860       True
# 861       True
# 862      False
# 863      False

# %%
# Symbols has two tests - we are using missing-previously-found-symbols
df = df[df["analysis"] != "missing-previously-found-exports"]

# %%
# Truth tables by predictor, first across all compilers
df["truth"] = False
for predictor in df['predictor'].unique():
    print('predictor: ', predictor)
    df_tmp = df[df['predictor'] == predictor]
    display(pandas.crosstab(df_tmp['prediction'], df_tmp['truth'], rownames=['prediction'], colnames=[predictor]))
# Out:
# predictor:  symbols
# symbols     False
# prediction
# False         168
# True           48
# predictor:  libabigail
# libabigail  False
# prediction
# False         216
# predictor:  abi-laboratory
# abi-laboratory  False
# prediction
# False             216

# %%
# Truth tables by predictor, first across all compilers
for predictor in df['predictor'].unique():
    for compiler in df['compiler'].unique():
        print('predictor: %s, compiler %s' %(predictor, compiler))
        df_tmp = df[(df['predictor'] == predictor) & (df['compiler'] == compiler)]
        display(pandas.crosstab(df_tmp['prediction'], df_tmp['truth'], rownames=['prediction'], colnames=[predictor]))
# Out:
# predictor: symbols, compiler clang-6
# symbols     False
# prediction
# False          14
# True            4
# predictor: symbols, compiler clang-10
# symbols     False
# prediction
# False          14
# True            4
# predictor: symbols, compiler clang-13
# symbols     False
# prediction
# False          14
# True            4
# predictor: symbols, compiler clang-12
# symbols     False
# prediction
# False          14
# True            4
# predictor: symbols, compiler clang-7
# symbols     False
# prediction
# False          14
# True            4
# predictor: symbols, compiler gcc-11.2.0
# symbols     False
# prediction
# False          14
# True            4
# predictor: symbols, compiler clang-8
# symbols     False
# prediction
# False          14
# True            4
# predictor: symbols, compiler gcc-9.4.0
# symbols     False
# prediction
# False          14
# True            4
# predictor: symbols, compiler clang-11
# symbols     False
# prediction
# False          14
# True            4
# predictor: symbols, compiler clang-14
# symbols     False
# prediction
# False          14
# True            4
# predictor: symbols, compiler gcc-7.5.0
# symbols     False
# prediction
# False          14
# True            4
# predictor: symbols, compiler dpcpp-2022.2
# symbols     False
# prediction
# False          14
# True            4
# predictor: libabigail, compiler clang-6
# libabigail  False
# prediction
# False          18
# predictor: libabigail, compiler clang-10
# libabigail  False
# prediction
# False          18
# predictor: libabigail, compiler clang-13
# libabigail  False
# prediction
# False          18
# predictor: libabigail, compiler clang-12
# libabigail  False
# prediction
# False          18
# predictor: libabigail, compiler clang-7
# libabigail  False
# prediction
# False          18
# predictor: libabigail, compiler gcc-11.2.0
# libabigail  False
# prediction
# False          18
# predictor: libabigail, compiler clang-8
# libabigail  False
# prediction
# False          18
# predictor: libabigail, compiler gcc-9.4.0
# libabigail  False
# prediction
# False          18
# predictor: libabigail, compiler clang-11
# libabigail  False
# prediction
# False          18
# predictor: libabigail, compiler clang-14
# libabigail  False
# prediction
# False          18
# predictor: libabigail, compiler gcc-7.5.0
# libabigail  False
# prediction
# False          18
# predictor: libabigail, compiler dpcpp-2022.2
# libabigail  False
# prediction
# False          18
# predictor: abi-laboratory, compiler clang-6
# abi-laboratory  False
# prediction
# False              18
# predictor: abi-laboratory, compiler clang-10
# abi-laboratory  False
# prediction
# False              18
# predictor: abi-laboratory, compiler clang-13
# abi-laboratory  False
# prediction
# False              18
# predictor: abi-laboratory, compiler clang-12
# abi-laboratory  False
# prediction
# False              18
# predictor: abi-laboratory, compiler clang-7
# abi-laboratory  False
# prediction
# False              18
# predictor: abi-laboratory, compiler gcc-11.2.0
# abi-laboratory  False
# prediction
# False              18
# predictor: abi-laboratory, compiler clang-8
# abi-laboratory  False
# prediction
# False              18
# predictor: abi-laboratory, compiler gcc-9.4.0
# abi-laboratory  False
# prediction
# False              18
# predictor: abi-laboratory, compiler clang-11
# abi-laboratory  False
# prediction
# False              18
# predictor: abi-laboratory, compiler clang-14
# abi-laboratory  False
# prediction
# False              18
# predictor: abi-laboratory, compiler gcc-7.5.0
# abi-laboratory  False
# prediction
# False              18
# predictor: abi-laboratory, compiler dpcpp-2022.2
# abi-laboratory  False
# prediction
# False              18
